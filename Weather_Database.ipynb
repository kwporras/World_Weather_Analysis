# %%
# Add Matplotlib inline magic command
# %matplotlib inline

# Import the dependencies.
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
from citipy import citipy

# https://stackoverflow.com/questions/59228094/module-not-found-error-no-module-named-config
import sys
sys.path.append('../')
import config

# %%
# Import the requests library.
import requests

# Import the API key.
from config import weather_api_key

# Starting URL for Weather Map API Call.
url = "http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=" + weather_api_key
print(url)
# Out:
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=90ff24e6baf8056be4dc85dd0908e927

# %%
# Create a set of random latitude and longitude combinations.
lats = np.random.uniform(low=-90.000, high=90.000, size=2000)
lngs = np.random.uniform(low=-180.000, high=180.000, size=2000)
lat_lngs = zip(lats, lngs)
lat_lngs

# %%
# Add the latitudes and longitudes to a list.
coordinates = list(lat_lngs)

# %%
# Create a list for holding the cities.
cities = []
# Identify the nearest city for each latitude and longitude combination.
for coordinate in coordinates:
    city = citipy.nearest_city(coordinate[0], coordinate[1]).city_name

    # If the city is unique, then we will add it to the cities list.
    if city not in cities:
        cities.append(city)
# Print the city count to confirm sufficient count.
len(cities)
# Out:
# 733

# %%
# Create an empty list to hold the weather data.
city_data = []
# Print the beginning of the logging.
print("Beginning Data Retrieval     ")
print("-----------------------------")

# Create counters.
record_count = 1
set_count = 1

# Loop through all the cities in the list.
for i, city in enumerate(cities):

    # Group cities in sets of 50 for logging purposes.
    if (i % 50 == 0 and i >= 50):
        set_count += 1
        record_count = 1
    # Create endpoint URL with each city.   
    city_url = url + "&q=" + city.replace(" ","+")

    # Log the URL, record, and set numbers and the city.
    print(f"Processing Record {record_count} of Set {set_count} | {city}")
    # Add 1 to the record count.
    record_count += 1


    # Run an API request for each of the cities.
    try:
        # Parse the JSON and retrieve data.
        city_weather = requests.get(city_url).json()
        # Parse out the needed data.
        city_lat = city_weather["coord"]["lat"]
        city_lng = city_weather["coord"]["lon"]
        city_max_temp = city_weather["main"]["temp_max"]
        city_humidity = city_weather["main"]["humidity"]
        city_clouds = city_weather["clouds"]["all"]
        city_wind = city_weather["wind"]["speed"]
        city_country = city_weather["sys"]["country"]
        city_description = city_weather["weather"][0]["description"]
        # Append the city information into city_data list.
        city_data.append({"City": city.title(),
                          "Lat": city_lat,
                          "Lng": city_lng,
                          "Max Temp": city_max_temp,
                          "Humidity": city_humidity,
                          "Cloudiness": city_clouds,
                          "Wind Speed": city_wind,
                          "Country": city_country,
                          "Current Description": city_description})

# If an error is experienced, skip the city.
    except:
        print("City not found. Skipping...")
        pass

# Indicate that Data Loading is complete.
print("-----------------------------")
print("Data Retrieval Complete      ")
print("-----------------------------")
# Out:
# Beginning Data Retrieval
# -----------------------------
# Processing Record 1 of Set 1 | bredasdorp
# Processing Record 2 of Set 1 | mackay
# Processing Record 3 of Set 1 | mataura
# Processing Record 4 of Set 1 | ushuaia
# Processing Record 5 of Set 1 | butaritari
# Processing Record 6 of Set 1 | lensk
# Processing Record 7 of Set 1 | mahebourg
# Processing Record 8 of Set 1 | richards bay
# Processing Record 9 of Set 1 | yellowknife
# Processing Record 10 of Set 1 | moerai
# Processing Record 11 of Set 1 | shieli
# Processing Record 12 of Set 1 | barrow
# Processing Record 13 of Set 1 | san patricio
# Processing Record 14 of Set 1 | albany
# Processing Record 15 of Set 1 | attawapiskat
# City not found. Skipping...
# Processing Record 16 of Set 1 | avarua
# Processing Record 17 of Set 1 | hermanus
# Processing Record 18 of Set 1 | kamenskoye
# City not found. Skipping...
# Processing Record 19 of Set 1 | ilulissat
# Processing Record 20 of Set 1 | cabedelo
# Processing Record 21 of Set 1 | lompoc
# Processing Record 22 of Set 1 | haibowan
# City not found. Skipping...
# Processing Record 23 of Set 1 | kapaa
# Processing Record 24 of Set 1 | ust-tarka
# Processing Record 25 of Set 1 | ribeira grande
# Processing Record 26 of Set 1 | hualmay
# Processing Record 27 of Set 1 | lavrentiya
# Processing Record 28 of Set 1 | vaini
# Processing Record 29 of Set 1 | aksarka
# Processing Record 30 of Set 1 | toliary
# City not found. Skipping...
# Processing Record 31 of Set 1 | mys shmidta
# City not found. Skipping...
# Processing Record 32 of Set 1 | maniitsoq
# Processing Record 33 of Set 1 | atuona
# Processing Record 34 of Set 1 | kargasok
# Processing Record 35 of Set 1 | ponta do sol
# Processing Record 36 of Set 1 | teya
# Processing Record 37 of Set 1 | kodiak
# Processing Record 38 of Set 1 | te anau
# Processing Record 39 of Set 1 | omboue
# Processing Record 40 of Set 1 | fortuna
# Processing Record 41 of Set 1 | shingu
# Processing Record 42 of Set 1 | busselton
# Processing Record 43 of Set 1 | taitung
# Processing Record 44 of Set 1 | campo grande
# Processing Record 45 of Set 1 | nikolskoye
# Processing Record 46 of Set 1 | saldanha
# Processing Record 47 of Set 1 | new norfolk
# Processing Record 48 of Set 1 | caxito
# Processing Record 49 of Set 1 | flinders
# Processing Record 50 of Set 1 | rikitea
# Processing Record 1 of Set 2 | walvis bay
# Processing Record 2 of Set 2 | tiksi
# Processing Record 3 of Set 2 | amderma
# City not found. Skipping...
# Processing Record 4 of Set 2 | kaitangata
# Processing Record 5 of Set 2 | banting
# Processing Record 6 of Set 2 | taltal
# Processing Record 7 of Set 2 | kavieng
# Processing Record 8 of Set 2 | norman wells
# Processing Record 9 of Set 2 | ancud
# Processing Record 10 of Set 2 | port alfred
# Processing Record 11 of Set 2 | hithadhoo
# Processing Record 12 of Set 2 | taoudenni
# Processing Record 13 of Set 2 | cape town
# Processing Record 14 of Set 2 | hobart
# Processing Record 15 of Set 2 | batagay
# Processing Record 16 of Set 2 | burica
# City not found. Skipping...
# Processing Record 17 of Set 2 | bluff
# Processing Record 18 of Set 2 | jamestown
# Processing Record 19 of Set 2 | palabuhanratu
# City not found. Skipping...
# Processing Record 20 of Set 2 | castro
# Processing Record 21 of Set 2 | leningradskiy
# Processing Record 22 of Set 2 | ayios matthaios
# City not found. Skipping...
# Processing Record 23 of Set 2 | nome
# Processing Record 24 of Set 2 | aquin
# Processing Record 25 of Set 2 | kutum
# Processing Record 26 of Set 2 | georgetown
# Processing Record 27 of Set 2 | jerome
# Processing Record 28 of Set 2 | ahipara
# Processing Record 29 of Set 2 | yulara
# Processing Record 30 of Set 2 | yatou
# Processing Record 31 of Set 2 | grand river south east
# City not found. Skipping...
# Processing Record 32 of Set 2 | eureka
# Processing Record 33 of Set 2 | hilo
# Processing Record 34 of Set 2 | tuatapere
# Processing Record 35 of Set 2 | illoqqortoormiut
# City not found. Skipping...
# Processing Record 36 of Set 2 | lieto
# Processing Record 37 of Set 2 | huambo
# Processing Record 38 of Set 2 | longyearbyen
# Processing Record 39 of Set 2 | teluk nibung
# Processing Record 40 of Set 2 | ola
# Processing Record 41 of Set 2 | san policarpo
# Processing Record 42 of Set 2 | puerto ayora
# Processing Record 43 of Set 2 | onega
# Processing Record 44 of Set 2 | springbok
# Processing Record 45 of Set 2 | am timan
# Processing Record 46 of Set 2 | hatillo
# Processing Record 47 of Set 2 | zachepylivka
# Processing Record 48 of Set 2 | sitka
# Processing Record 49 of Set 2 | torbay
# Processing Record 50 of Set 2 | taolanaro
# City not found. Skipping...
# Processing Record 1 of Set 3 | bainbridge
# Processing Record 2 of Set 3 | cockburn town
# Processing Record 3 of Set 3 | zhicheng
# Processing Record 4 of Set 3 | fremont
# Processing Record 5 of Set 3 | saint george
# Processing Record 6 of Set 3 | cabo san lucas
# Processing Record 7 of Set 3 | innisfail
# Processing Record 8 of Set 3 | shache
# Processing Record 9 of Set 3 | iqaluit
# Processing Record 10 of Set 3 | praia da vitoria
# Processing Record 11 of Set 3 | tuktoyaktuk
# Processing Record 12 of Set 3 | acapulco
# Processing Record 13 of Set 3 | gornopravdinsk
# Processing Record 14 of Set 3 | fort saint james
# Processing Record 15 of Set 3 | punta arenas
# Processing Record 16 of Set 3 | karla
# Processing Record 17 of Set 3 | provideniya
# Processing Record 18 of Set 3 | port elizabeth
# Processing Record 19 of Set 3 | ust-bolsheretsk
# City not found. Skipping...
# Processing Record 20 of Set 3 | owando
# Processing Record 21 of Set 3 | saskylakh
# Processing Record 22 of Set 3 | narsaq
# Processing Record 23 of Set 3 | mokrousovo
# Processing Record 24 of Set 3 | palana
# Processing Record 25 of Set 3 | la rochelle
# Processing Record 26 of Set 3 | la joya
# Processing Record 27 of Set 3 | thompson
# Processing Record 28 of Set 3 | barra patuca
# Processing Record 29 of Set 3 | chuy
# Processing Record 30 of Set 3 | loyga
# Processing Record 31 of Set 3 | naze
# Processing Record 32 of Set 3 | roma
# Processing Record 33 of Set 3 | namibe
# Processing Record 34 of Set 3 | lebu
# Processing Record 35 of Set 3 | victoria
# Processing Record 36 of Set 3 | muhos
# Processing Record 37 of Set 3 | sentyabrskiy
# City not found. Skipping...
# Processing Record 38 of Set 3 | tessalit
# Processing Record 39 of Set 3 | sao filipe
# Processing Record 40 of Set 3 | pevek
# Processing Record 41 of Set 3 | abu samrah
# Processing Record 42 of Set 3 | kruisfontein
# Processing Record 43 of Set 3 | port augusta
# Processing Record 44 of Set 3 | souillac
# Processing Record 45 of Set 3 | khatanga
# Processing Record 46 of Set 3 | amahai
# Processing Record 47 of Set 3 | bengkulu
# Processing Record 48 of Set 3 | caravelas
# Processing Record 49 of Set 3 | berwick
# Processing Record 50 of Set 3 | utiroa
# City not found. Skipping...
# Processing Record 1 of Set 4 | avera
# Processing Record 2 of Set 4 | ambulu
# Processing Record 3 of Set 4 | birjand
# Processing Record 4 of Set 4 | dalbandin
# Processing Record 5 of Set 4 | deputatskiy
# Processing Record 6 of Set 4 | nizhneyansk
# City not found. Skipping...
# Processing Record 7 of Set 4 | bulgan
# Processing Record 8 of Set 4 | saint-philippe
# Processing Record 9 of Set 4 | teguise
# Processing Record 10 of Set 4 | barentsburg
# City not found. Skipping...
# Processing Record 11 of Set 4 | bubaque
# Processing Record 12 of Set 4 | paso de patria
# Processing Record 13 of Set 4 | ostrovnoy
# Processing Record 14 of Set 4 | port blair
# Processing Record 15 of Set 4 | atasu
# Processing Record 16 of Set 4 | idil
# Processing Record 17 of Set 4 | lubin
# Processing Record 18 of Set 4 | krasnorechenskiy
# Processing Record 19 of Set 4 | prince rupert
# Processing Record 20 of Set 4 | okhotsk
# Processing Record 21 of Set 4 | maracaibo
# Processing Record 22 of Set 4 | chaohu
# Processing Record 23 of Set 4 | east london
# Processing Record 24 of Set 4 | katherine
# Processing Record 25 of Set 4 | morwell
# Processing Record 26 of Set 4 | burnie
# Processing Record 27 of Set 4 | oleksandrivka
# Processing Record 28 of Set 4 | westport
# Processing Record 29 of Set 4 | qaanaaq
# Processing Record 30 of Set 4 | alyangula
# Processing Record 31 of Set 4 | meadow lake
# Processing Record 32 of Set 4 | kahului
# Processing Record 33 of Set 4 | magadan
# Processing Record 34 of Set 4 | lakes entrance
# Processing Record 35 of Set 4 | kushima
# Processing Record 36 of Set 4 | college
# Processing Record 37 of Set 4 | neiafu
# Processing Record 38 of Set 4 | griffith
# Processing Record 39 of Set 4 | talaya
# Processing Record 40 of Set 4 | solnechnyy
# Processing Record 41 of Set 4 | agirish
# Processing Record 42 of Set 4 | gat
# Processing Record 43 of Set 4 | vestmannaeyjar
# Processing Record 44 of Set 4 | caconda
# Processing Record 45 of Set 4 | mar del plata
# Processing Record 46 of Set 4 | chokurdakh
# Processing Record 47 of Set 4 | severo-kurilsk
# Processing Record 48 of Set 4 | manaure
# Processing Record 49 of Set 4 | kysyl-syr
# Processing Record 50 of Set 4 | bermeo
# Processing Record 1 of Set 5 | vardo
# Processing Record 2 of Set 5 | jiwani
# Processing Record 3 of Set 5 | cidreira
# Processing Record 4 of Set 5 | ilhabela
# Processing Record 5 of Set 5 | limbang
# Processing Record 6 of Set 5 | sungaipenuh
# Processing Record 7 of Set 5 | ballina
# Processing Record 8 of Set 5 | berlevag
# Processing Record 9 of Set 5 | aksehir
# Processing Record 10 of Set 5 | mezhdurechensk
# Processing Record 11 of Set 5 | lolua
# City not found. Skipping...
# Processing Record 12 of Set 5 | sorland
# Processing Record 13 of Set 5 | saint-pierre
# Processing Record 14 of Set 5 | alice springs
# Processing Record 15 of Set 5 | aykhal
# Processing Record 16 of Set 5 | madang
# Processing Record 17 of Set 5 | vila velha
# Processing Record 18 of Set 5 | albert
# Processing Record 19 of Set 5 | arlit
# Processing Record 20 of Set 5 | taua
# Processing Record 21 of Set 5 | guder
# Processing Record 22 of Set 5 | vila franca do campo
# Processing Record 23 of Set 5 | fevralsk
# City not found. Skipping...
# Processing Record 24 of Set 5 | juneau
# Processing Record 25 of Set 5 | fallon
# Processing Record 26 of Set 5 | west wendover
# Processing Record 27 of Set 5 | vao
# Processing Record 28 of Set 5 | carnarvon
# Processing Record 29 of Set 5 | rawson
# Processing Record 30 of Set 5 | torbat-e jam
# Processing Record 31 of Set 5 | gisborne
# Processing Record 32 of Set 5 | jalu
# Processing Record 33 of Set 5 | antofagasta
# Processing Record 34 of Set 5 | guerrero negro
# Processing Record 35 of Set 5 | amazar
# Processing Record 36 of Set 5 | talnakh
# Processing Record 37 of Set 5 | baijiantan
# Processing Record 38 of Set 5 | port hardy
# Processing Record 39 of Set 5 | china
# Processing Record 40 of Set 5 | luderitz
# Processing Record 41 of Set 5 | buraydah
# Processing Record 42 of Set 5 | gibsons
# Processing Record 43 of Set 5 | gorontalo
# Processing Record 44 of Set 5 | fairbanks
# Processing Record 45 of Set 5 | borogontsy
# Processing Record 46 of Set 5 | lasa
# Processing Record 47 of Set 5 | coquimbo
# Processing Record 48 of Set 5 | marawi
# Processing Record 49 of Set 5 | tsihombe
# City not found. Skipping...
# Processing Record 50 of Set 5 | yining
# Processing Record 1 of Set 6 | nanortalik
# Processing Record 2 of Set 6 | camacupa
# Processing Record 3 of Set 6 | mahanoro
# Processing Record 4 of Set 6 | lagoa
# Processing Record 5 of Set 6 | ulaanbaatar
# Processing Record 6 of Set 6 | polunochnoye
# Processing Record 7 of Set 6 | cherskiy
# Processing Record 8 of Set 6 | port lincoln
# Processing Record 9 of Set 6 | santa marta
# Processing Record 10 of Set 6 | ongandjera
# Processing Record 11 of Set 6 | bisira
# Processing Record 12 of Set 6 | bukene
# Processing Record 13 of Set 6 | porto uniao
# Processing Record 14 of Set 6 | lephepe
# City not found. Skipping...
# Processing Record 15 of Set 6 | faanui
# Processing Record 16 of Set 6 | halalo
# City not found. Skipping...
# Processing Record 17 of Set 6 | ngaoundere
# Processing Record 18 of Set 6 | hasaki
# Processing Record 19 of Set 6 | broome
# Processing Record 20 of Set 6 | sri aman
# Processing Record 21 of Set 6 | ternate
# Processing Record 22 of Set 6 | kavaratti
# Processing Record 23 of Set 6 | tocache
# Processing Record 24 of Set 6 | conway
# Processing Record 25 of Set 6 | piacabucu
# Processing Record 26 of Set 6 | goderich
# Processing Record 27 of Set 6 | kodigenahalli
# Processing Record 28 of Set 6 | bayir
# Processing Record 29 of Set 6 | daru
# Processing Record 30 of Set 6 | itoman
# Processing Record 31 of Set 6 | yumen
# Processing Record 32 of Set 6 | la ronge
# Processing Record 33 of Set 6 | iguape
# Processing Record 34 of Set 6 | makakilo city
# Processing Record 35 of Set 6 | vila
# Processing Record 36 of Set 6 | dawei
# Processing Record 37 of Set 6 | tasiilaq
# Processing Record 38 of Set 6 | samarai
# Processing Record 39 of Set 6 | pisco
# Processing Record 40 of Set 6 | robertsport
# Processing Record 41 of Set 6 | bambous virieux
# Processing Record 42 of Set 6 | kaduy
# Processing Record 43 of Set 6 | flin flon
# Processing Record 44 of Set 6 | chateauroux
# Processing Record 45 of Set 6 | tumannyy
# City not found. Skipping...
# Processing Record 46 of Set 6 | bontang
# Processing Record 47 of Set 6 | noumea
# Processing Record 48 of Set 6 | tabiauea
# City not found. Skipping...
# Processing Record 49 of Set 6 | geraldton
# Processing Record 50 of Set 6 | laiya
# Processing Record 1 of Set 7 | dikson
# Processing Record 2 of Set 7 | klisura
# Processing Record 3 of Set 7 | sao joao da barra
# Processing Record 4 of Set 7 | soledade
# Processing Record 5 of Set 7 | verkhnetulomskiy
# Processing Record 6 of Set 7 | vaitape
# Processing Record 7 of Set 7 | vaitupu
# City not found. Skipping...
# Processing Record 8 of Set 7 | upernavik
# Processing Record 9 of Set 7 | kimamba
# Processing Record 10 of Set 7 | keti bandar
# Processing Record 11 of Set 7 | khuzhir
# Processing Record 12 of Set 7 | riviere-au-renard
# Processing Record 13 of Set 7 | clyde river
# Processing Record 14 of Set 7 | road town
# Processing Record 15 of Set 7 | kununurra
# Processing Record 16 of Set 7 | tucuman
# Processing Record 17 of Set 7 | bacungan
# Processing Record 18 of Set 7 | khani
# Processing Record 19 of Set 7 | pankrushikha
# Processing Record 20 of Set 7 | nedjo
# Processing Record 21 of Set 7 | cairns
# Processing Record 22 of Set 7 | belushya guba
# City not found. Skipping...
# Processing Record 23 of Set 7 | jinchengjiang
# City not found. Skipping...
# Processing Record 24 of Set 7 | trapani
# Processing Record 25 of Set 7 | gunjur
# Processing Record 26 of Set 7 | salalah
# Processing Record 27 of Set 7 | jinji
# Processing Record 28 of Set 7 | arraial do cabo
# Processing Record 29 of Set 7 | bethel
# Processing Record 30 of Set 7 | esso
# Processing Record 31 of Set 7 | ixtapa
# Processing Record 32 of Set 7 | nanga eboko
# Processing Record 33 of Set 7 | simbahan
# Processing Record 34 of Set 7 | airai
# Processing Record 35 of Set 7 | paragominas
# Processing Record 36 of Set 7 | acarau
# Processing Record 37 of Set 7 | zima
# Processing Record 38 of Set 7 | umzimvubu
# City not found. Skipping...
# Processing Record 39 of Set 7 | flexeiras
# Processing Record 40 of Set 7 | rudbar
# Processing Record 41 of Set 7 | novo cruzeiro
# Processing Record 42 of Set 7 | kandrian
# Processing Record 43 of Set 7 | mogadishu
# Processing Record 44 of Set 7 | hambantota
# Processing Record 45 of Set 7 | canico
# Processing Record 46 of Set 7 | panevezys
# Processing Record 47 of Set 7 | xinmin
# Processing Record 48 of Set 7 | kudahuvadhoo
# Processing Record 49 of Set 7 | cayenne
# Processing Record 50 of Set 7 | qasigiannguit
# Processing Record 1 of Set 8 | mazagao
# Processing Record 2 of Set 8 | hami
# Processing Record 3 of Set 8 | chagda
# City not found. Skipping...
# Processing Record 4 of Set 8 | sur
# Processing Record 5 of Set 8 | log
# Processing Record 6 of Set 8 | mayo
# Processing Record 7 of Set 8 | pangnirtung
# Processing Record 8 of Set 8 | cowra
# Processing Record 9 of Set 8 | inirida
# Processing Record 10 of Set 8 | zlatoustovsk
# City not found. Skipping...
# Processing Record 11 of Set 8 | xuddur
# Processing Record 12 of Set 8 | maragogi
# Processing Record 13 of Set 8 | along
# Processing Record 14 of Set 8 | marsh harbour
# Processing Record 15 of Set 8 | chapais
# Processing Record 16 of Set 8 | nuevo progreso
# Processing Record 17 of Set 8 | isangel
# Processing Record 18 of Set 8 | hazorasp
# Processing Record 19 of Set 8 | port hedland
# Processing Record 20 of Set 8 | louisbourg
# City not found. Skipping...
# Processing Record 21 of Set 8 | gaillac
# Processing Record 22 of Set 8 | hamilton
# Processing Record 23 of Set 8 | manjeshwar
# Processing Record 24 of Set 8 | saryshagan
# City not found. Skipping...
# Processing Record 25 of Set 8 | kloulklubed
# Processing Record 26 of Set 8 | tongren
# Processing Record 27 of Set 8 | tabou
# Processing Record 28 of Set 8 | evensk
# Processing Record 29 of Set 8 | cedar city
# Processing Record 30 of Set 8 | fort nelson
# Processing Record 31 of Set 8 | oktyabrskoye
# Processing Record 32 of Set 8 | korsakov
# Processing Record 33 of Set 8 | champerico
# Processing Record 34 of Set 8 | saleaula
# City not found. Skipping...
# Processing Record 35 of Set 8 | asau
# Processing Record 36 of Set 8 | sohag
# Processing Record 37 of Set 8 | sambava
# Processing Record 38 of Set 8 | sant feliu de guixols
# Processing Record 39 of Set 8 | poya
# Processing Record 40 of Set 8 | santa eulalia del rio
# City not found. Skipping...
# Processing Record 41 of Set 8 | soyo
# Processing Record 42 of Set 8 | katobu
# Processing Record 43 of Set 8 | porto novo
# Processing Record 44 of Set 8 | eydhafushi
# Processing Record 45 of Set 8 | lorengau
# Processing Record 46 of Set 8 | kieta
# Processing Record 47 of Set 8 | rincon
# Processing Record 48 of Set 8 | kidal
# Processing Record 49 of Set 8 | lima
# Processing Record 50 of Set 8 | saint-joseph
# Processing Record 1 of Set 9 | chateaubelair
# Processing Record 2 of Set 9 | hounde
# Processing Record 3 of Set 9 | peniche
# Processing Record 4 of Set 9 | bethanien
# Processing Record 5 of Set 9 | bathsheba
# Processing Record 6 of Set 9 | boyolangu
# Processing Record 7 of Set 9 | mildura
# Processing Record 8 of Set 9 | dwarka
# Processing Record 9 of Set 9 | asmar
# Processing Record 10 of Set 9 | richmond
# Processing Record 11 of Set 9 | moose factory
# Processing Record 12 of Set 9 | nushki
# Processing Record 13 of Set 9 | thinadhoo
# Processing Record 14 of Set 9 | mehamn
# Processing Record 15 of Set 9 | porbandar
# Processing Record 16 of Set 9 | sept-iles
# Processing Record 17 of Set 9 | karratha
# Processing Record 18 of Set 9 | husavik
# Processing Record 19 of Set 9 | nibbar
# Processing Record 20 of Set 9 | honningsvag
# Processing Record 21 of Set 9 | payakumbuh
# Processing Record 22 of Set 9 | constitucion
# Processing Record 23 of Set 9 | garh maharaja
# Processing Record 24 of Set 9 | codrington
# Processing Record 25 of Set 9 | ibra
# Processing Record 26 of Set 9 | bredy
# Processing Record 27 of Set 9 | ambunti
# Processing Record 28 of Set 9 | nishihara
# Processing Record 29 of Set 9 | buchanan
# Processing Record 30 of Set 9 | abu jubayhah
# City not found. Skipping...
# Processing Record 31 of Set 9 | jackson
# Processing Record 32 of Set 9 | srednekolymsk
# Processing Record 33 of Set 9 | esperance
# Processing Record 34 of Set 9 | batagay-alyta
# Processing Record 35 of Set 9 | lazaro cardenas
# Processing Record 36 of Set 9 | grindavik
# Processing Record 37 of Set 9 | iracoubo
# Processing Record 38 of Set 9 | mountain home
# Processing Record 39 of Set 9 | omutninsk
# Processing Record 40 of Set 9 | melfort
# Processing Record 41 of Set 9 | marzanesti
# Processing Record 42 of Set 9 | riyadh
# Processing Record 43 of Set 9 | manitouwadge
# Processing Record 44 of Set 9 | visnes
# Processing Record 45 of Set 9 | celestun
# Processing Record 46 of Set 9 | belle fourche
# Processing Record 47 of Set 9 | kurilsk
# Processing Record 48 of Set 9 | turkistan
# Processing Record 49 of Set 9 | tambovka
# Processing Record 50 of Set 9 | siilinjarvi
# Processing Record 1 of Set 10 | raudeberg
# Processing Record 2 of Set 10 | pleshanovo
# Processing Record 3 of Set 10 | mount gambier
# Processing Record 4 of Set 10 | meyungs
# City not found. Skipping...
# Processing Record 5 of Set 10 | matamoros
# Processing Record 6 of Set 10 | lazy
# Processing Record 7 of Set 10 | labutta
# City not found. Skipping...
# Processing Record 8 of Set 10 | cabras
# Processing Record 9 of Set 10 | klaksvik
# Processing Record 10 of Set 10 | ubajara
# Processing Record 11 of Set 10 | cockburn harbour
# City not found. Skipping...
# Processing Record 12 of Set 10 | palmer
# Processing Record 13 of Set 10 | christchurch
# Processing Record 14 of Set 10 | dingle
# Processing Record 15 of Set 10 | qui nhon
# Processing Record 16 of Set 10 | manado
# Processing Record 17 of Set 10 | verkhnevilyuysk
# Processing Record 18 of Set 10 | koudougou
# Processing Record 19 of Set 10 | kankan
# Processing Record 20 of Set 10 | iralaya
# Processing Record 21 of Set 10 | sangar
# Processing Record 22 of Set 10 | margate
# Processing Record 23 of Set 10 | belonia
# Processing Record 24 of Set 10 | nelson
# Processing Record 25 of Set 10 | fonte boa
# Processing Record 26 of Set 10 | jansath
# Processing Record 27 of Set 10 | itarema
# Processing Record 28 of Set 10 | diffa
# Processing Record 29 of Set 10 | butiama
# Processing Record 30 of Set 10 | marapanim
# Processing Record 31 of Set 10 | ouadda
# Processing Record 32 of Set 10 | peace river
# Processing Record 33 of Set 10 | the valley
# Processing Record 34 of Set 10 | bandarbeyla
# Processing Record 35 of Set 10 | srikakulam
# Processing Record 36 of Set 10 | sataua
# City not found. Skipping...
# Processing Record 37 of Set 10 | khuzdar
# Processing Record 38 of Set 10 | hofn
# Processing Record 39 of Set 10 | viedma
# Processing Record 40 of Set 10 | miranda
# Processing Record 41 of Set 10 | alugan
# Processing Record 42 of Set 10 | ranong
# Processing Record 43 of Set 10 | we
# City not found. Skipping...
# Processing Record 44 of Set 10 | sobolevo
# Processing Record 45 of Set 10 | xixiang
# Processing Record 46 of Set 10 | fredericton
# Processing Record 47 of Set 10 | cap malheureux
# Processing Record 48 of Set 10 | tura
# Processing Record 49 of Set 10 | ratnagiri
# Processing Record 50 of Set 10 | nisia floresta
# Processing Record 1 of Set 11 | wawa
# Processing Record 2 of Set 11 | vostok
# Processing Record 3 of Set 11 | andenes
# Processing Record 4 of Set 11 | cabatuan
# Processing Record 5 of Set 11 | rawah
# Processing Record 6 of Set 11 | kabalo
# Processing Record 7 of Set 11 | pacifica
# Processing Record 8 of Set 11 | korla
# Processing Record 9 of Set 11 | domoni
# Processing Record 10 of Set 11 | coahuayana
# Processing Record 11 of Set 11 | san quintin
# Processing Record 12 of Set 11 | lages
# Processing Record 13 of Set 11 | matagami
# Processing Record 14 of Set 11 | grants pass
# Processing Record 15 of Set 11 | mokshan
# Processing Record 16 of Set 11 | buy
# Processing Record 17 of Set 11 | bilibino
# Processing Record 18 of Set 11 | tilichiki
# Processing Record 19 of Set 11 | haines junction
# Processing Record 20 of Set 11 | dubenskiy
# City not found. Skipping...
# Processing Record 21 of Set 11 | auki
# Processing Record 22 of Set 11 | whitehorse
# Processing Record 23 of Set 11 | manzil jamil
# City not found. Skipping...
# Processing Record 24 of Set 11 | laredo
# Processing Record 25 of Set 11 | bilma
# Processing Record 26 of Set 11 | weligama
# Processing Record 27 of Set 11 | san jeronimo
# Processing Record 28 of Set 11 | sinkat
# City not found. Skipping...
# Processing Record 29 of Set 11 | nouadhibou
# Processing Record 30 of Set 11 | maykain
# City not found. Skipping...
# Processing Record 31 of Set 11 | linqiong
# Processing Record 32 of Set 11 | polyarnyye zori
# Processing Record 33 of Set 11 | grand-lahou
# Processing Record 34 of Set 11 | davlekanovo
# Processing Record 35 of Set 11 | george
# Processing Record 36 of Set 11 | olhao
# Processing Record 37 of Set 11 | colares
# Processing Record 38 of Set 11 | kaset sombun
# Processing Record 39 of Set 11 | beringovskiy
# Processing Record 40 of Set 11 | puerto ayacucho
# Processing Record 41 of Set 11 | channel-port aux basques
# Processing Record 42 of Set 11 | minsk
# Processing Record 43 of Set 11 | katsuura
# Processing Record 44 of Set 11 | quibor
# Processing Record 45 of Set 11 | paita
# Processing Record 46 of Set 11 | progreso
# Processing Record 47 of Set 11 | nyurba
# Processing Record 48 of Set 11 | jomalig
# City not found. Skipping...
# Processing Record 49 of Set 11 | meulaboh
# Processing Record 50 of Set 11 | caldas novas
# Processing Record 1 of Set 12 | svetlogorsk
# Processing Record 2 of Set 12 | calama
# Processing Record 3 of Set 12 | lebrija
# Processing Record 4 of Set 12 | seymchan
# Processing Record 5 of Set 12 | rocha
# Processing Record 6 of Set 12 | at-bashi
# Processing Record 7 of Set 12 | aklavik
# Processing Record 8 of Set 12 | gushikawa
# Processing Record 9 of Set 12 | portland
# Processing Record 10 of Set 12 | port moresby
# Processing Record 11 of Set 12 | omsukchan
# Processing Record 12 of Set 12 | chimore
# Processing Record 13 of Set 12 | maryville
# Processing Record 14 of Set 12 | kropotkin
# Processing Record 15 of Set 12 | udachnyy
# Processing Record 16 of Set 12 | havre-saint-pierre
# Processing Record 17 of Set 12 | ruatoria
# City not found. Skipping...
# Processing Record 18 of Set 12 | oranjemund
# Processing Record 19 of Set 12 | alofi
# Processing Record 20 of Set 12 | arvi
# Processing Record 21 of Set 12 | hovd
# Processing Record 22 of Set 12 | san cristobal
# Processing Record 23 of Set 12 | nuristan
# Processing Record 24 of Set 12 | laguna
# Processing Record 25 of Set 12 | vestmanna
# Processing Record 26 of Set 12 | awbari
# Processing Record 27 of Set 12 | kaili
# Processing Record 28 of Set 12 | sao gabriel da cachoeira
# Processing Record 29 of Set 12 | winnemucca
# Processing Record 30 of Set 12 | tocopilla
# Processing Record 31 of Set 12 | sao felix do xingu
# Processing Record 32 of Set 12 | opuwo
# Processing Record 33 of Set 12 | nawa
# Processing Record 34 of Set 12 | adrar
# Processing Record 35 of Set 12 | kamenka
# Processing Record 36 of Set 12 | kirakira
# Processing Record 37 of Set 12 | oxapampa
# Processing Record 38 of Set 12 | aloleng
# Processing Record 39 of Set 12 | impfondo
# Processing Record 40 of Set 12 | viligili
# City not found. Skipping...
# Processing Record 41 of Set 12 | ucluelet
# Processing Record 42 of Set 12 | boa vista
# Processing Record 43 of Set 12 | las palmas
# Processing Record 44 of Set 12 | chimbarongo
# Processing Record 45 of Set 12 | menongue
# Processing Record 46 of Set 12 | sembe
# Processing Record 47 of Set 12 | yanchukan
# City not found. Skipping...
# Processing Record 48 of Set 12 | tubruq
# City not found. Skipping...
# Processing Record 49 of Set 12 | alenquer
# Processing Record 50 of Set 12 | amapa
# Processing Record 1 of Set 13 | beyneu
# Processing Record 2 of Set 13 | dubrovnik
# Processing Record 3 of Set 13 | olafsvik
# Processing Record 4 of Set 13 | stoyba
# City not found. Skipping...
# Processing Record 5 of Set 13 | andreyevo
# Processing Record 6 of Set 13 | mazamari
# Processing Record 7 of Set 13 | porto belo
# Processing Record 8 of Set 13 | parauna
# Processing Record 9 of Set 13 | yar-sale
# Processing Record 10 of Set 13 | aktau
# Processing Record 11 of Set 13 | oriximina
# Processing Record 12 of Set 13 | chilliwack
# Processing Record 13 of Set 13 | tommot
# Processing Record 14 of Set 13 | hervey bay
# Processing Record 15 of Set 13 | yinchuan
# Processing Record 16 of Set 13 | rapid city
# Processing Record 17 of Set 13 | stokmarknes
# Processing Record 18 of Set 13 | palu
# Processing Record 19 of Set 13 | faya
# Processing Record 20 of Set 13 | ihlow
# Processing Record 21 of Set 13 | shipitsyno
# Processing Record 22 of Set 13 | lianyuan
# Processing Record 23 of Set 13 | ust-kamchatsk
# City not found. Skipping...
# Processing Record 24 of Set 13 | bolungarvik
# City not found. Skipping...
# Processing Record 25 of Set 13 | caen
# Processing Record 26 of Set 13 | ardmore
# Processing Record 27 of Set 13 | mossendjo
# Processing Record 28 of Set 13 | banda aceh
# Processing Record 29 of Set 13 | lata
# Processing Record 30 of Set 13 | havoysund
# Processing Record 31 of Set 13 | tsienyane
# City not found. Skipping...
# Processing Record 32 of Set 13 | qaqortoq
# Processing Record 33 of Set 13 | ariyalur
# Processing Record 34 of Set 13 | paamiut
# Processing Record 35 of Set 13 | abu zabad
# Processing Record 36 of Set 13 | bandundu
# Processing Record 37 of Set 13 | aflu
# City not found. Skipping...
# Processing Record 38 of Set 13 | timra
# Processing Record 39 of Set 13 | bac lieu
# Processing Record 40 of Set 13 | zvishavane
# Processing Record 41 of Set 13 | ostersund
# Processing Record 42 of Set 13 | marabba
# Processing Record 43 of Set 13 | ruidoso
# Processing Record 44 of Set 13 | marcona
# City not found. Skipping...
# Processing Record 45 of Set 13 | cooma
# Processing Record 46 of Set 13 | chumikan
# Processing Record 47 of Set 13 | ishigaki
# Processing Record 48 of Set 13 | diego de almagro
# Processing Record 49 of Set 13 | westerland
# Processing Record 50 of Set 13 | ponta delgada
# Processing Record 1 of Set 14 | alekseyevsk
# Processing Record 2 of Set 14 | ksenyevka
# City not found. Skipping...
# Processing Record 3 of Set 14 | shebunino
# Processing Record 4 of Set 14 | sinnamary
# Processing Record 5 of Set 14 | altay
# Processing Record 6 of Set 14 | pangkalanbuun
# Processing Record 7 of Set 14 | nanakuli
# Processing Record 8 of Set 14 | bowen
# Processing Record 9 of Set 14 | quelimane
# Processing Record 10 of Set 14 | sesheke
# Processing Record 11 of Set 14 | abu kamal
# Processing Record 12 of Set 14 | santander
# Processing Record 13 of Set 14 | mwinilunga
# Processing Record 14 of Set 14 | almirante
# Processing Record 15 of Set 14 | preeceville
# Processing Record 16 of Set 14 | nanlong
# Processing Record 17 of Set 14 | murwillumbah
# Processing Record 18 of Set 14 | kushmurun
# Processing Record 19 of Set 14 | ahuimanu
# Processing Record 20 of Set 14 | nagyoroszi
# Processing Record 21 of Set 14 | serendah
# Processing Record 22 of Set 14 | la libertad
# Processing Record 23 of Set 14 | port macquarie
# Processing Record 24 of Set 14 | bargal
# City not found. Skipping...
# Processing Record 25 of Set 14 | marquette
# Processing Record 26 of Set 14 | tautira
# Processing Record 27 of Set 14 | grand gaube
# Processing Record 28 of Set 14 | matay
# Processing Record 29 of Set 14 | santiago
# Processing Record 30 of Set 14 | warqla
# City not found. Skipping...
# Processing Record 31 of Set 14 | beloha
# Processing Record 32 of Set 14 | semnan
# Processing Record 33 of Set 14 | vidim
# Processing Record 34 of Set 14 | kamalpur
# Processing Record 35 of Set 14 | vila do maio
# Processing Record 36 of Set 14 | seka
# Processing Record 37 of Set 14 | rio grande
# Processing Record 38 of Set 14 | gizo
# Processing Record 39 of Set 14 | turka
# Processing Record 40 of Set 14 | shamary
# Processing Record 41 of Set 14 | kaka
# Processing Record 42 of Set 14 | wanning
# Processing Record 43 of Set 14 | dashitou
# Processing Record 44 of Set 14 | tiznit
# Processing Record 45 of Set 14 | cepu
# Processing Record 46 of Set 14 | merauke
# Processing Record 47 of Set 14 | nizwa
# Processing Record 48 of Set 14 | komsomolskiy
# Processing Record 49 of Set 14 | yaan
# Processing Record 50 of Set 14 | pitimbu
# Processing Record 1 of Set 15 | brandon
# Processing Record 2 of Set 15 | amuntai
# Processing Record 3 of Set 15 | zacatepec
# Processing Record 4 of Set 15 | maldonado
# Processing Record 5 of Set 15 | moindou
# Processing Record 6 of Set 15 | kyra
# Processing Record 7 of Set 15 | novosysoyevka
# Processing Record 8 of Set 15 | chantada
# Processing Record 9 of Set 15 | roald
# Processing Record 10 of Set 15 | henties bay
# Processing Record 11 of Set 15 | samusu
# City not found. Skipping...
# Processing Record 12 of Set 15 | grand centre
# City not found. Skipping...
# Processing Record 13 of Set 15 | simao
# Processing Record 14 of Set 15 | staraya kulatka
# Processing Record 15 of Set 15 | huinan
# Processing Record 16 of Set 15 | kosonsoy
# Processing Record 17 of Set 15 | belle glade
# Processing Record 18 of Set 15 | pa sang
# Processing Record 19 of Set 15 | boende
# Processing Record 20 of Set 15 | artyk
# City not found. Skipping...
# Processing Record 21 of Set 15 | hunza
# City not found. Skipping...
# Processing Record 22 of Set 15 | sioux lookout
# Processing Record 23 of Set 15 | zhigansk
# Processing Record 24 of Set 15 | tucurui
# Processing Record 25 of Set 15 | karakendzha
# City not found. Skipping...
# Processing Record 26 of Set 15 | touros
# Processing Record 27 of Set 15 | lerwick
# Processing Record 28 of Set 15 | kamskiye polyany
# Processing Record 29 of Set 15 | uthal
# Processing Record 30 of Set 15 | utiel
# Processing Record 31 of Set 15 | dolbeau
# City not found. Skipping...
# Processing Record 32 of Set 15 | harigue
# City not found. Skipping...
# Processing Record 33 of Set 15 | boyuibe
# -----------------------------
# Data Retrieval Complete
# -----------------------------

# %%
# Convert the array of dictionaries to a Pandas DataFrame.
city_data_df = pd.DataFrame(city_data)
city_data_df
# Out:
#                  City      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# 0          Bredasdorp -34.5322   20.0403     51.12        66          56
# 1              Mackay -21.1500  149.2000     68.04        94           2
# 2             Mataura -46.1927  168.8643     46.47        82          39
# 3             Ushuaia -54.8000  -68.3000     44.26        76          75
# 4          Butaritari   3.0707  172.7902     82.81        70          16
# ..                ...      ...       ...       ...       ...         ...
# 663           Lerwick  60.1545   -1.1494     57.20        98          98
# 664  Kamskiye Polyany  55.4307   51.4171     52.61        69           5
# 665             Uthal  25.8072   66.6219     82.26        84          95
# 666             Utiel  39.5667   -1.2000     69.10        81           0
# 667           Boyuibe -20.4167  -63.2833     58.91        36           7
#
#      Wind Speed Country      Current Description
# 0          9.22      ZA            broken clouds
# 1          4.61      AU                clear sky
# 2          4.21      NZ         scattered clouds
# 3          4.61      AR  light intensity drizzle
# 4         10.22      KI               few clouds
# ..          ...     ...                      ...
# 663       10.31      GB          overcast clouds
# 664        4.12      RU                clear sky
# 665        4.18      PK          overcast clouds
# 666        5.01      ES                clear sky
# 667        6.06      BO                clear sky
#
# [668 rows x 9 columns]

# %%
new_column_order = ["City", "Country", "Lat", "Lng", "Max Temp", "Humidity", "Cloudiness", "Wind Speed", "Current Description"]
city_data_df = city_data_df[new_column_order]
city_data_df
# Out:
#                  City Country      Lat       Lng  Max Temp  Humidity  \
# 0          Bredasdorp      ZA -34.5322   20.0403     51.12        66
# 1              Mackay      AU -21.1500  149.2000     68.04        94
# 2             Mataura      NZ -46.1927  168.8643     46.47        82
# 3             Ushuaia      AR -54.8000  -68.3000     44.26        76
# 4          Butaritari      KI   3.0707  172.7902     82.81        70
# ..                ...     ...      ...       ...       ...       ...
# 663           Lerwick      GB  60.1545   -1.1494     57.20        98
# 664  Kamskiye Polyany      RU  55.4307   51.4171     52.61        69
# 665             Uthal      PK  25.8072   66.6219     82.26        84
# 666             Utiel      ES  39.5667   -1.2000     69.10        81
# 667           Boyuibe      BO -20.4167  -63.2833     58.91        36
#
#      Cloudiness  Wind Speed      Current Description
# 0            56        9.22            broken clouds
# 1             2        4.61                clear sky
# 2            39        4.21         scattered clouds
# 3            75        4.61  light intensity drizzle
# 4            16       10.22               few clouds
# ..          ...         ...                      ...
# 663          98       10.31          overcast clouds
# 664           5        4.12                clear sky
# 665          95        4.18          overcast clouds
# 666           0        5.01                clear sky
# 667           7        6.06                clear sky
#
# [668 rows x 9 columns]

# %%
# Create the output file (CSV).
output_data_file = "Weather_Database/WeatherPy_Database.csv"
# Export the City_Data into a CSV.
city_data_df.to_csv(output_data_file, index_label="City_ID")
